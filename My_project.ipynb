# %%
# !wget --no-check-certificate \
-O gencode.vM27.annotation.gtf.gz \
http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Out:
# --2025-05-29 19:12:26--  http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28359457 (27M) [application/x-gzip]
# Saving to: ‘gencode.vM27.annotation.gtf.gz’
#
# gencode.vM27.annota 100%[===================>]  27.04M  2.47MB/s    in 23s
#
# 2025-05-29 19:12:49 (1.20 MB/s) - ‘gencode.vM27.annotation.gtf.gz’ saved [28359457/28359457]

# %%
# !gunzip /home/jieunlisa/bioinfo_work/gencode.vM27.annotation.gtf.gz
